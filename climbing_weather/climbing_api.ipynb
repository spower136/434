# %%
# https://app.swaggerhub.com/apis-docs/climbing-weather/cw-api/4.0#/
# https://www.climbingweather.com/api

# %%
import requests
import json
import pandas as pd
import sys
# !{sys.executable} -m pip install openpyxl
import openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 2.4 MB/s
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3 -m pip install --upgrade pip' command.

# %%
response = requests.get('https://api.climbingweather.com')
print(response)
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.climbingweather.com/country/US/adminArea')
print(response.json())
# Out:
# [{'country': 'US', 'code': 'AK', 'name': 'Alaska', 'areaCount': 3, 'swLatitude': None, 'swLongitude': None, 'neLatitude': None, 'neLongitude': None}, {'country': 'US', 'code': 'AL', 'name': 'Alabama', 'areaCount': 13, 'swLatitude': None, 'swLongitude': None, 'neLatitude': None, 'neLongitude': None}, {'country': 'US', 'code': 'AR', 'name': 'Arkansas', 'areaCount': 9, 'swLatitude': None, 'swLongitude': None, 'neLatitude': None, 'neLongitude': None}, {'country': 'US', 'code': 'AZ', 'name': 'Arizona', 'areaCount': 43, 'swLatitude': None, 'swLongitude': None, 'neLatitude': None, 'neLongitude': None}, {'country': 'US', 'code': 'CA', 'name': 'California', 'areaCount': 141, 'swLatitude': None, 'swLongitude': None, 'neLatitude': None, 'neLongitude': None}, {'country': 'US', 'code': 'CO', 'name': 'Colorado', 'areaCount': 92, 'swLatitude': None, 'swLongitude': None, 'neLatitude': None, 'neLongitude': None}, {'country': 'US', 'code': 'CT', 'name': 'Connecticut', 'areaCount': 3, 'swLatitude': Non
# ...

# %%
request = requests.get('https://api.climbingweather.com/country/US/area')
response = request.json()


df = pd.DataFrame.from_dict(response)
df
# Out:
#      areaId country adminArea adminAreaName                    name  \
# 0       756     USA        ME         Maine    Acadia National Park
# 1         4     USA        NY      New York             Adirondacks
# 2       729     USA        CA    California           Alabama Hills
# 3      1083     USA        CA    California               Alta Peak
# 4       715     USA        UT          Utah    American Fork Canyon
# ..      ...     ...       ...           ...                     ...
# 614     657     USA        WI     Wisconsin           Wyalusing ice
# 615     894     USA        AL       Alabama            Yellow Bluff
# 616     518     USA        CA    California  Yosemite National Park
# 617     641     USA        UT          Utah      Zion National Park
# 618     905     USA        AZ       Arizona        Zoroaster Temple
#
#       latitude    longitude forecast
# 0    44.339600   -68.258100     None
# 1    44.190000   -73.810000     None
# ...

# %%
filtered_df = df.loc[(df['adminArea'] == 'ME') | (df['adminArea'] == 'CO')]
filtered_df
# Out:
#      areaId country adminArea adminAreaName                  name   latitude  \
# 0       756     USA        ME         Maine  Acadia National Park  44.339600
# 10      837     USA        CO      Colorado         Arthur's Rock  40.561049
# 25      831     USA        CO      Colorado       Big Elk Meadows  40.277781
# 33      748     USA        CO      Colorado          Black Canyon  38.544540
# 38      974     USA        CO      Colorado           Blanca Peak  37.577200
# ..      ...     ...       ...           ...                   ...        ...
# 580    1001     USA        CO      Colorado       Ute Valley Park  38.911800
# 583     836     USA        CO      Colorado             Vail Pass  39.512938
# 587     981     USA        CO      Colorado           Vestal Peak  37.689400
# 595    1071     USA        CO      Colorado       Waterton Canyon  38.863260
# 605    1065     USA        CO      Colorado            Wild Basin  40.209318
#
#        longitude forecast
# ...

# %%
filtered_df.to_excel('output.xlsx')
